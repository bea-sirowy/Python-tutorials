# %% [markdown]
# Beata Sirowy
# # __Networked technology__
#
# Based on Severance, Ch. (2016) _Python for Everybody. Exploring Data in Python 3_

# %% [markdown]
# ## TCP connections - an overview

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Hypertext transfer protocol (HTTP)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Protocol

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### An HTTP request in Python
#
# - we create a socket
# - make connection to the port
# - send a request
# - get data back

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(("data.pr4e.org", 80))
cmd = "GET http://data.pr4e.org/romeo.txt HTTP/1.0\n\n" .encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if(len(data) < 1):
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 400 Bad Request
# Date: Wed, 30 Oct 2024 17:54:20 GMT
# Server: Apache/2.4.52 (Ubuntu)
# Content-Length: 308
# Connection: close
# Content-Type: text/html; charset=iso-8859-1
#
# <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>400 Bad Request</title>
# </head><body>
# <h1>Bad Request</h1>
# <p>Your browser sent a request that this server could not understand.<br />
# </p>
# <hr>
# <address>Apache/2.4.52 (Ubuntu) Server at do1.dr-chuck.com Port 80</address>
# </body></html>

# %% [markdown]
# ### A
