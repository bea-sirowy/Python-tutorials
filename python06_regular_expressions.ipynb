# %% [markdown]
# Beata Sirowy
# # __Regular expressions__
#
# Based on Severance, Ch. (2016) _Python for Everybody. Exploring Data in Python 3_

# %% [markdown]
# ## An overview
# - a programming language of "marker characters"
# - "old school" - very compact
# - a way to reduce the amont of code - instead of programming with lines we program with characters
# - used also with other languages - e.g. SQL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![regular_expressions.png](attachment:regular_expressions.png)

# %% [markdown]
# https://xkcd.com/208/

# %% [markdown]
# ## RE in Python

# %% [markdown]
# - we must import the library using "import re"
# - we can use __re.search()__  to see if a stringf matches a regular expression, similar to using the __find()__ or __startswith()__ methods for strings - see the examples below

# %%
document=open(r"C:\Users\Beata\Documents\Python Scripts\mbox-short.txt")
for line in document:
    line = line.rstrip()
    if line.find('From: g') >= 0:
        print(line)
# Out:
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gopal.ramasammycook@gmail.com

# %%
document=open(r"C:\Users\Beata\Documents\Python Scripts\mbox-short.txt")
for line in document:
    line = line.rstrip()
    if line.startswith('From: g'):
        print(line)
# Out:
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gopal.ramasammycook@gmail.com

# %%
import re

document=open(r"C:\Users\Beata\Documents\Python Scripts\mbox-short.txt")
for line in document:
    line = line.rstrip()
    if re.search('From: g', line):
        print(line)
# Out:
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gopal.ramasammycook@gmail.com

# %%
import re

document=open(r"C:\Users\Beata\Documents\Python Scripts\mbox-short.txt")
for line in document:
    line = line.rstrip()
    if re.search('^From: g', line): #Here we use a special character ^ (starts with) 
        print(line)
# Out:
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: gopal.ramasammycook@gmail.com

# %% [markdown]
# - we can use __re.findall()__ to extract portions of a string that match our regular expression, similar to a combination of find() and slicing: var[5:10]

# %% [markdown]
# ### Wild-card characters

# %% [markdown]
# - dot . matches __any character__
# - asterisk * means __any number of times - 0 or more__ <br>
# e.g. __^X.*:__ means: X at the beginning of a line, followed by 0 or more characters forllowed by a colon - this matches all of the following expressions:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We may want to narrow down the following match:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We modify the regular expression to exclude the results with whitespace

# %% [markdown]
# ![image.png](attachment:image.png)
